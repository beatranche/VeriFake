# %% [markdown]
# ### Análisis de Noticias Falsas y Reales en Español
#
# #### Introducción
# Este notebook está diseñado para procesar, analizar y visualizar datos de noticias falsas y reales en español. Se basa en una combinación de bases de datos generadas a partir de scraping y otras fuentes. El objetivo principal es realizar un preprocesamiento exhaustivo de los datos, preparar las características textuales, y generar visualizaciones que permitan entender mejor la distribución de las noticias, sus fuentes y características textuales. Finalmente, los datos procesados serán guardados en un archivo `csv` limpio para su posterior uso en modelos de machine learning.
#
# #### Objetivos
# 1. **Descarga y procesamiento de datos**: Se descargan varias bases de datos de noticias en español, incluyendo noticias reales y falsas. Los datos se limpian y combinan en un único DataFrame.
# 2. **Preprocesamiento de texto**: Se preprocesa el texto eliminando caracteres no deseados, realizando lematización y eliminando stopwords.
# 3. **Análisis exploratorio de datos**: Se generan varias visualizaciones que permiten entender la distribución de las noticias y características textuales, como:
#    - Distribución de noticias falsas vs reales.
#    - Principales fuentes de noticias.
#    - Distribución de la longitud de los textos (número de caracteres).
#    - Nubes de palabras para noticias falsas y reales.
# 4. **Exportación de datos procesados**: Se guarda un archivo `CSV` que contiene los datos procesados y listos para ser utilizados en modelos de clasificación de noticias falsas y clickbait.
#
# #### Pasos detallados
# 1. **Cargar y preprocesar los datos**: Se descargan varios datasets en formato CSV desde diferentes fuentes, incluyendo scraping de páginas web, y se realizan las siguientes operaciones:
#    - Renombrar columnas.
#    - Limpiar datos faltantes.
#    - Combinar las bases de datos en un único DataFrame.
#
# 2. **Preprocesamiento del texto**:
#    - Se eliminan caracteres especiales no alfabéticos.
#    - Se convierten todos los textos a minúsculas.
#    - Se realiza la lematización utilizando la biblioteca `spacy` en español.
#    - Se eliminan stopwords utilizando el conjunto de stopwords en español de `nltk`.
#
# 3. **Exploración de los datos**:
#    - **Distribución de categorías**: Se genera un gráfico de barras para mostrar el número de noticias falsas y reales.
#    - **Distribución de fuentes**: Se genera un gráfico de las principales fuentes de noticias.
#    - **Longitud de textos**: Se calcula y visualiza la longitud de los textos en términos de caracteres, comparando noticias falsas y reales.
#    - **Nubes de palabras**: Se generan nubes de palabras para identificar las palabras más comunes tanto en noticias falsas como en noticias reales.
#
# 4. **Exportación de datos**: El DataFrame final, después del procesamiento, se guarda en un archivo `CSV` llamado `fake_news_clean.csv` para ser utilizado en futuros modelos de clasificación o análisis.

# %%
import pandas as pd
import warnings
import spacy
import nltk
import re

# %%
# Cargar y preprocesar datos
df1 = pd.read_csv("hf://datasets/mariagrandury/fake_news_corpus_spanish/test.csv")
df2 = pd.read_csv("https://huggingface.co/datasets/sayalaruano/FakeNewsCorpusSpanish/raw/main/train.csv")
df3 = pd.read_csv('https://drive.google.com/uc?export=download&id=16925KI3IS1_IajpDS65VR8gInzWsQ1ZR')

# %%
df1.head(2)
# Out:
#    ID  CATEGORY    TOPICS         SOURCE  \
# 0   1      True  Covid-19  El Economista
# 1   2     False  Política     El matinal
#
#                                             HEADLINE  \
# 0                       Covid-19: mentiras que matan
# 1  El Gobierno podrá acceder a las IPs de los móv...
#
#                                                 TEXT  \
# 0  El control de la Covid-19 no es sólo un tema d...
# 1  El Gobierno de Pedro Sánchez y Pablo Iglesias ...
#
#                                                 LINK
# 0  https://www.eleconomista.com.mx/opinion/Covid-...
# 1  https://www.elmatinal.com/espana-ultima-hora/e...

# %%
df2.head(2)
# Out:
#    Id Category      Topic          Source  \
# 0   1     Fake  Education  El Ruinaversal
# 1   2     Fake  Education     Hay noticia
#
#                                             Headline  \
# 0  RAE INCLUIRÁ LA PALABRA "LADY" EN EL DICCIONAR...
# 1            La palabra "haiga", aceptada por la RAE
#
#                                                 Text  \
# 0  RAE INCLUIRÁ LA PALABRA "LADY" EN EL DICCIONAR...
# 1  La palabra "haiga", aceptada por la RAE La Rea...
#
#                                                 Link
# 0  http://www.elruinaversal.com/2017/06/10/rae-in...
# 1  https://haynoticia.es/la-palabra-haiga-aceptad...

# %%
df3.head(2)
# Out:
#    Id Category      Topic          Source  \
# 0   1     Fake  Education  El Ruinaversal
# 1   2     True  Education         Heraldo
#
#                                             Headline  \
# 0  MAESTRA DE *NUMBER* AÑOS QUE TUVO RELACIONES C...
# 1  Oxford lanza sus propios exámenes de certifica...
#
#                                                 Text  \
# 0  MAESTRA DE *NUMBER* AÑOS QUE TUVO RELACIONES C...
# 1  Oxford lanza sus propios exámenes de certifica...
#
#                                                 Link
# 0  http://www.elruinaversal.com/2017/06/04/maestr...
# 1  https://www.heraldo.es/noticias/sociedad/2017/...

# %%
# Renombrar columnas y procesar texto
for df in [df1, df2, df3]:
    df.rename(columns={"ID": "Id", "CATEGORY": "Category", "TOPICS": "Topic", "SOURCE": "Source", "HEADLINE": "Headline", "TEXT": "Text", "LINK": "Link"}, inplace=True)
    df['Category'].replace({'Fake': False, 'True': True, 'False': False}, inplace=True)
    df['Category'] = df['Category'].map({True: 1, False: 0})
# Out:
# C:\Users\eslab\AppData\Local\Temp\ipykernel_11656\1308117329.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Category'].replace({'Fake': False, 'True': True, 'False': False}, inplace=True)
# C:\Users\eslab\AppData\Local\Temp\ipykernel_11656\1308117329.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Category'].replace({'Fake': False, 'True': True, 'False': False}, inplace=True)

# %%
# Combinar los dataframes
df_combined = pd.concat([df1, df2, df3])

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1543 entries, 0 to 294
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        1543 non-null   int64
#  1   Category  1543 non-null   int64
#  2   Topic     1543 non-null   object
#  3   Source    1536 non-null   object
#  4   Headline  1471 non-null   object
#  5   Text      1543 non-null   object
#  6   Link      1540 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 96.4+ KB

# %%
df_combined.value_counts()
# Out:
# Id   Category  Topic          Source          Headline                                                                                                     Text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 1    0         Education      El Ruinaversal  MAESTRA DE *NUMBER* AÑOS QUE TUVO RELACIONES CON UN ALUMNO DE *NUMBER* DARÁ EDUCACIÓN SEXUAL EN EL CONALEP   MAESTRA DE *NUMBER* AÑOS QUE TUVO RELACIONES CON UN ALUMNO DE *NUMBER* DARÁ EDUCACIÓN SEXUAL EN EL CONALEP\nEstados Unidos.- Luego de que se revelará el caso de una maestra
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
#                Covid-19       BBC News        Nueva cepa del coronavirus: la cancelación masiva de vuelos y trenes con Reino Unido                         Amplios sectores del sureste de Reino Unido, incluyendo la capital, Londres, están ahora bajo nuevas y más estrictas restricciones a fin de frenar la rápida propagación del virus, aunque no hay indicios de que la mutación aumente la mortalidad del virus. La Organización Mundial de la Salud (OMS) informó que está en "contacto cercano" con las autoridades británicas para dar seguimiento a la investigación.\n\nMás de 40 países suspendieron los vuelos con Reino Unido, entre ellos Alemania, Italia, Bélgica, Irlanda, España, Argentina y Chile.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 676  0         Entertainment  La voz popular  MUERTE DE PETER EL ANGUILA POR SOBREDOSIS                                                                    MUERTE DE PETER EL ANGUILA POR SOBREDOSIS\nPeter el Anguila, el último fenómeno Youtube gracias a su famoso baile "El estilo de Peter el Anguila" que ha conseguido desbancar al "Gangnam Style" en los últimos meses apareció muerto por sobredosis de cocaína en el camerino de uno de sus conciertos.\nYa eran conocidas en el mundo musical las historias de Peter el Anguila y sus adicciones a la cocaína, aún así, la noticia ha sorprendido a sus allegados. Peter el Anguila hacía meses que había dejado la cocaína, nunca imaginaron que esto pudiera acabar con su vida.\nCircunstancias de la muerte de Peter el Anguila\nTodo sucedió en el concierto del pasado martes, Peter el Anguila desapareció tras su última canción, su agente le buscó por todos sitios pero no había ni rastro de él, hasta que vieron que la puerta del baño de su camerino estaba cerrada, de una patada abrieron la puerta y se encontraron a Peter el Anguila muerto por sobredosis.\nAsí se encontró el cadáver de Peter el Anguila muerto\nTras su muerte por sobredosis, Peter el Anguila deja a su mujer, Mary la Trucha con dos niños, un perro, el caballo de Atila y las tres bailarinas que le acompañan en su famoso vídeo de "El estilo de Peter el Anguila.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# Name: count, Length: 1468, dtype: int64

# %%
# Limpiar datos faltantes
df_combined['Headline'].fillna(df_combined['Text'].apply(lambda x: ' '.join(x.split()[:10])), inplace=True)
df_combined.dropna(subset=['Source'], inplace=True)
df_combined['Link'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\eslab\AppData\Local\Temp\ipykernel_11656\1114374163.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_combined['Headline'].fillna(df_combined['Text'].apply(lambda x: ' '.join(x.split()[:10])), inplace=True)
# C:\Users\eslab\AppData\Local\Temp\ipykernel_11656\1114374163.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_combined['Link'].fillna('Unknown', inplace=True)

# %%
df_combined.head(3)
# Out:
#    Id  Category     Topic         Source  \
# 0   1         1  Covid-19  El Economista
# 1   2         0  Política     El matinal
# 2   3         1  Política        El País
#
#                                             Headline  \
# 0                       Covid-19: mentiras que matan
# 1  El Gobierno podrá acceder a las IPs de los móv...
# 2  La comunidad musulmana catalana denuncia a Vox...
#
#                                                 Text  \
# 0  El control de la Covid-19 no es sólo un tema d...
# 1  El Gobierno de Pedro Sánchez y Pablo Iglesias ...
# 2  Las tres federaciones que agrupan al 90% de la...
#
#                                                 Link
# 0  https://www.eleconomista.com.mx/opinion/Covid-...
# 1  https://www.elmatinal.com/espana-ultima-hora/e...
# 2  https://elpais.com/espana/elecciones-catalanas...

# %%
df_combined.isnull().sum()
# Out:
# Id          0
# Category    0
# Topic       0
# Source      0
# Headline    0
# Text        0
# Link        0
# dtype: int64

# %%
df_combined.duplicated().sum()
# Out:
# 0

# %%
df_google_news = pd.read_csv('../data/real_news.csv')
df_concat = pd.read_csv('../data/google_scrap.csv')
df_more = pd.read_csv('../data/more.csv')
df_news = pd.read_csv('../data/news.csv')
df_real_news_google = pd.read_csv('../data/real_news_google.csv')
df_real_news = pd.read_csv('../data/real_news.csv')

# %%
df_concat = pd.concat([df_google_news, df_concat, df_more, df_news, df_real_news_google, df_real_news])

# %%
df_concat.value_counts()
# Out:
# query             position  title                                                                                                              body                                                                                                                                              posted           source                    link
# para              36        Andalucía destinará en su presupuesto de 2025 casi 6.700 millones para el \ntejido productivo                      La consejera de Economía, Hacienda y Fondos Europeos de la Junta de \nAndalucía, Carolina España, anuncia que los Presupuestos autonómicos ...    hace 51 minutos  El Economista             https://www.eleconomista.es/economia/noticias/13042723/10/24/andalucia-destinara-en-su-presupuesto-de-2025-casi-6700-millones-para-el-tejido-productivo.html      2
#                   18        El Gobierno publica en el BOE la convocatoria para la selección de 26 \nplazas de Policía Local                    Un total de 21 de estas plazas va destinado al sistema de acceso de turno \nlibre, mientras que las cinco restantes quedan reservadas para...     hace 13 minutos  Ayuntamiento de Chiclana  https://www.chiclana.es/noticias/detalle-noticia/el-gobierno-publica-en-el-boe-la-convocatoria-para-la-seleccion-de-26-plazas-de-policia-local                    2
# Internacional     7         Jordi Valls califica de “éxito” la Copa America por la proyección \ninternacional de Barcelona                     El teniente de alcalde de Economía deja en el aire que la ciudad vuelva a \nalbergar el evento, pendiente de una conversación con Grant...        Hace 1 día       El Español                https://metropoliabierta.elespanol.com/economia/20241020/jordi-valls-califica-de-exito-la-copa-america-por-proyeccion-internacional-barcelona/894910506_0.html    2
# para              12        El director de la primera película censurada en democracia resucita para \nreivindicar las películas que no hizo   Fernando Ruiz Vergara vivió la censura de su documental 'Rocío' y el cine \nespañol se perdió la carrera de un cineasta prometedor.               hace 13 horas    elDiario.es               https://www.eldiario.es/cultura/cine/director-primera-pelicula-censurada-democracia-resucita-reivindicar-peliculas-no-hizo_1_11747865.html                        2
#                   13        Las farmacias navarras sufren desabastecimiento del principal medicamento \npara el TDAH                           Las farmacias navarras llevan varias semanas con desabastecimiento de \nConcerta, uno de los principales medicamentos para tratar el TDAH...      hace 13 horas    Noticias de Navarra       https://www.noticiasdenavarra.com/actualidad/2024/10/20/farmacias-navarras-sufren-desabastecimiento-principal-8829843.html                                        2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ..
# León              48        San Froilán regala otro puente a León                                                                              Para 2025, San Froilán vendrá en León con un puente debajo del brazo. El \nAyuntamiento de la capital leonesa ha decidido mantener el 5 de...     hace 9 horas     Diario de León            https://www.diariodeleon.es/leon/241021/1656376/san-froilan-regala-puente-leon.html                                                                               1
#                   49        Mañueco encabeza una misión económica a París y Bruselas para impulsar la \ncompetitividad de Castilla y León      El martes mantendrá una reunión con la Dirección de Renault en París, en la \nsede que la compañía tiene en la capital francesa.                  hace 4 horas     ABC                       https://www.abc.es/espana/castilla-leon/manueco-encabeza-mision-economica-paris-bruselas-impulsar-20241021073520-nt.html                                          1
#                   50        El CEL pide al acalde de León facilitar el retorno de talento y un entorno \neconómico más dinámico y competitivo  Medio centenar de empresarios, directivos y autónomos del CEL mantuvieron \nuna comida-coloquio con el regidor leonés en la Bodega Regia para...  hace 3 horas     León24horas               https://leon24horas.net/actualidad/el-cel-pide-al-acalde-de-leon-facilitar-el-retorno-de-talento-y-un-entorno-economico-mas-dinamico-y-competitivo/               1
#                   51        El Dulce Nombre cede varias tallas para el Museo de la Semana Santa de León                                        La Cofradía del Dulce Nombre de Jesús Nazareno y la Fundación Museo \nDiocesano y de Semana Santa de León han suscrito el pasado viernes un...    hace 2 horas     León24horas               https://leon24horas.net/actualidad/el-dulce-nombre-cede-varias-tallas-para-el-museo-de-la-semana-santa-de-leon/                                                   1
# Últimas noticias  30        Guerra Israel-Palestina y Rusia-Ucrania: últimas noticias del 15 de octubre                                        Sigue en vivo y en directo la última hora del conflicto que libra Israel en \nGaza y Líbano, la guerra entre Rusia y Ucrania y la última hora...  Hace 5 días      Diario AS                 https://as.com/actualidad/politica/guerra-israel-palestina-y-rusia-ucrania-en-directo-netanyahu-detalla-a-eeuu-como-sera-su-posible-ataque-a-iran-n/              1
# Name: count, Length: 831, dtype: int64

# %%
df_concat.isnull().sum()
# Out:
# query        0
# position     0
# title        3
# body        79
# posted      79
# source       3
# link         0
# dtype: int64

# %%
df_concat.duplicated().sum()
# Out:
# 308

# %%
df_concat = df_concat.drop_duplicates()
df_concat = df_concat.dropna()

# %%
df_concat.shape
# Out:
# (831, 7)

# %%
# Renombrar columnas
df_concat = df_concat.rename(columns={'title': 'Headline', 'body': 'Text', 'link': 'Link'})

# Añadir columna 'Category' con valor 1 en todas las filas
df_concat['Category'] = 1

# Verificar los cambios
df_concat.head()
# Out:
#   query  position                                           Headline  \
# 0  para         1  Muriqi, un regreso perfecto para un Mallorca q...
# 1  para         2  Intervienen en Chiclana una red de grandes dim...
# 2  para         3  Jota Jordi suelta esta bomba en directo para h...
# 7  para         8  El referéndum en Moldavia para blindar la vía ...
# 8  para         9  Adiós al transporte público gratuito para todo...
#
#                                                 Text           posted  \
# 0  El 'pirata' volvió al equipo tras un mes de le...  hace 20 minutos
# 1  La Policía autonómica ha rescatado a una docen...  hace 30 minutos
# 2  El tertuliano del Chiringuito está tan seguro ...     hace 3 horas
# 7  Moldavia denuncia un ataque “sin precedentes” ...    hace 14 horas
# 8  El descuento en el transporte público finaliza...     hace 5 horas
#
#             source                                               Link  \
# 0        Marca.com  https://www.marca.com/futbol/mallorca/2024/10/...
# 1  Diario de Cádiz  https://www.diariodecadiz.es/chiclana/intervie...
# 2        Diario AS  https://as.com/futbol/videos/jota-jordi-suelta...
# 7          EL PAÍS  https://elpais.com/internacional/2024-10-20/el...
# 8        20Minutos  https://www.20minutos.es/lainformacion/economi...
#
#    Category
# 0         1
# 1         1
# 2         1
# 7         1
# 8         1

# %%
# Renombrar columnas para concatenar ambos datasets
df_concat = df_concat[['Headline', 'Text', 'Link', 'Category']]  
df_combined = df_combined[['Id', 'Category', 'Topic', 'Source', 'Headline', 'Text', 'Link']]

# %%
# Añadir columnas vacías a df_google_scrap para alinearlo con el segundo dataset
df_concat['Id'] = range(1, len(df_concat) + 1)  # Asignar un Id único a cada fila
df_concat['Topic'] = 'Unknown'  # Añadir columna Topic con un valor predeterminado
df_concat['Source'] = 'Unknown'  # Añadir columna Source con un valor predeterminado

# Ordenar las columnas para que coincidan con el segundo dataset
df_concat = df_concat[['Id', 'Category', 'Topic', 'Source', 'Headline', 'Text', 'Link']]

# Combinar ambos datasets
df_combined = pd.concat([df_combined, df_concat], ignore_index=True)

# Verificar el dataset combinado
df_combined.head()
# Out:
#    Id  Category     Topic         Source  \
# 0   1         1  Covid-19  El Economista
# 1   2         0  Política     El matinal
# 2   3         1  Política        El País
# 3   4         0  Política     AFPFactual
# 4   5         1  Sociedad   La Republica
#
#                                             Headline  \
# 0                       Covid-19: mentiras que matan
# 1  El Gobierno podrá acceder a las IPs de los móv...
# 2  La comunidad musulmana catalana denuncia a Vox...
# 3  Se han dado a conocer los datos electorales pr...
# 4  El censo poblacional 2018 tendrá un costo de $...
#
#                                                 Text  \
# 0  El control de la Covid-19 no es sólo un tema d...
# 1  El Gobierno de Pedro Sánchez y Pablo Iglesias ...
# 2  Las tres federaciones que agrupan al 90% de la...
# 3  Se han dado a conocer los datos electorales pr...
# 4  La primera fase del censo será virtual y solo ...
#
#                                                 Link
# 0  https://www.eleconomista.com.mx/opinion/Covid-...
# 1  https://www.elmatinal.com/espana-ultima-hora/e...
# 2  https://elpais.com/espana/elecciones-catalanas...
# 3                         https://perma.cc/GYE6-SPMB
# 4  https://www.larepublica.co/economia/el-censo-p...

# %%
df_combined.shape
# Out:
# (2367, 7)

# %%
df_combined.isnull().sum()
# Out:
# Id          0
# Category    0
# Topic       0
# Source      0
# Headline    0
# Text        0
# Link        0
# dtype: int64

# %%
df_combined.Category.value_counts()
# Out:
# Category
# 1    1606
# 0     761
# Name: count, dtype: int64

# %%
df_fake_news = pd.read_csv('../data/headline_links_combined.csv')

# %%
df_fake_news.head()
# Out:
#    Index                                           Headline  \
# 0      0  “En el AIFA hay más ratas que vuelos”, afirmau...
# 1      0  Afirmaciones similares circulan en Twitter (1,...
# 2      0  El Aeropuerto Internacional Felipe Ángeles (AI...
# 3      0  Sin embargo, el Felipe Ángeles ha tardado en a...
# 4      0  “La gente sigue sin darse cuenta pero esto es ...
#
#                                                 Link
# 0                                 https://aifa.aero/
# 1  https://www.nytimes.com/es/2022/03/25/espanol/...
# 2                           https://www.aicm.com.mx/
# 3  https://www.aicm.com.mx/acercadelaicm/archivos...
# 4  https://www.latribune.fr/entreprises-finance/b...

# %%
df_fake_news.shape
# Out:
# (12514, 3)

# %%
df_fnews = df_fake_news.sample(1000)

# %%
df_fnews = df_fnews.rename(columns={'Headline': 'Text'})
df_fnews['Category'] = 0

# %%
df_fnews.head(2)
# Out:
#       Index                                               Text  \
# 2866      4  @Valentivalientees una cuenta de Twitter quese...
# 3544      5  En realidad es una visualización 3D de los inc...
#
#                                                    Link  Category
# 2866  https://www.facebook.com/VOXEspana/photos/a.49...         0
# 3544  https://maldita.es/uploads/public/martadelola.png         0

# %%
# Concatenar ambos DataFrames usando las columnas comunes
df_combined = pd.concat([df_combined, df_fnews], ignore_index=True)

# Ver las primeras filas del nuevo DataFrame unido
df_combined.head()
# Out:
#     Id  Category     Topic         Source  \
# 0  1.0         1  Covid-19  El Economista
# 1  2.0         0  Política     El matinal
# 2  3.0         1  Política        El País
# 3  4.0         0  Política     AFPFactual
# 4  5.0         1  Sociedad   La Republica
#
#                                             Headline  \
# 0                       Covid-19: mentiras que matan
# 1  El Gobierno podrá acceder a las IPs de los móv...
# 2  La comunidad musulmana catalana denuncia a Vox...
# 3  Se han dado a conocer los datos electorales pr...
# 4  El censo poblacional 2018 tendrá un costo de $...
#
#                                                 Text  \
# 0  El control de la Covid-19 no es sólo un tema d...
# 1  El Gobierno de Pedro Sánchez y Pablo Iglesias ...
# 2  Las tres federaciones que agrupan al 90% de la...
# 3  Se han dado a conocer los datos electorales pr...
# 4  La primera fase del censo será virtual y solo ...
#
#                                                 Link  Index
# 0  https://www.eleconomista.com.mx/opinion/Covid-...    NaN
# 1  https://www.elmatinal.com/espana-ultima-hora/e...    NaN
# 2  https://elpais.com/espana/elecciones-catalanas...    NaN
# 3                         https://perma.cc/GYE6-SPMB    NaN
# 4  https://www.larepublica.co/economia/el-censo-p...    NaN

# %%
df_combined.isnull().sum()
# Out:
# Id          1000
# Category       0
# Topic       1000
# Source      1000
# Headline    1000
# Text           0
# Link           0
# Index       2367
# dtype: int64

# %%
columns_to_drop = ['Topic', 'Source', 'Headline','Index', 'Id']  # Cambia los nombres de las columnas según sea necesario

# Eliminar las columnas específicas
df_combined = df_combined.drop(columns=columns_to_drop)

# %%
df_combined.head(2)
# Out:
#    Category                                               Text  \
# 0         1  El control de la Covid-19 no es sólo un tema d...
# 1         0  El Gobierno de Pedro Sánchez y Pablo Iglesias ...
#
#                                                 Link
# 0  https://www.eleconomista.com.mx/opinion/Covid-...
# 1  https://www.elmatinal.com/espana-ultima-hora/e...

# %%
# Extraer el nombre del dominio
df_combined['Source'] = df_combined['Link'].str.extract(r'https?://(?:www\.)?([^/]+)')

# %%
df_combined.head(2)
# Out:
#    Category                                               Text  \
# 0         1  El control de la Covid-19 no es sólo un tema d...
# 1         0  El Gobierno de Pedro Sánchez y Pablo Iglesias ...
#
#                                                 Link               Source
# 0  https://www.eleconomista.com.mx/opinion/Covid-...  eleconomista.com.mx
# 1  https://www.elmatinal.com/espana-ultima-hora/e...        elmatinal.com

# %%
df_combined['Source'] = df_combined['Source'].str.split('.').str[0]

# %%
df_combined.head(2)
# Out:
#    Category                                               Text  \
# 0         1  El control de la Covid-19 no es sólo un tema d...
# 1         0  El Gobierno de Pedro Sánchez y Pablo Iglesias ...
#
#                                                 Link        Source
# 0  https://www.eleconomista.com.mx/opinion/Covid-...  eleconomista
# 1  https://www.elmatinal.com/espana-ultima-hora/e...     elmatinal

# %%
# Descargar stopwords
nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('spanish'))

# Cargar modelo de spacy
nlp = spacy.load('es_core_news_sm')

# Función de preprocesamiento
def preprocess_text(text):
    text = re.sub(r'[^a-zA-ZáéíóúñÁÉÍÓÚÑ\s]', '', text)  # Eliminar caracteres no alfabéticos
    text = text.lower()  # Convertir a minúsculas
    doc = nlp(text)
    return ' '.join([token.lemma_ for token in doc if token.text not in stop_words and not token.is_punct])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eslab\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_combined['Text'] = df_combined['Text'].apply(preprocess_text)

# %%
df_combined.shape
# Out:
# (3322, 5)

# %%
df_combined.dropna(inplace=True)

# %%
df_combined.to_csv('../data/fake_news_clean.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Gráfico de barras para la distribución de categorías (Fake vs Real)
plt.figure(figsize=(6, 4))
sns.countplot(x='Category', data=df_combined)
plt.title('Distribución de Noticias Falsas vs Reales')
plt.xlabel('Categoría (0: Fake, 1: Real)')
plt.ylabel('Número de Noticias')
plt.show()

# %%
# Contar el número de noticias por fuente
fuente_count = df_combined['Source'].value_counts().head(10)  # Mostrar las 10 fuentes principales

# Gráfico de barras para las fuentes principales
plt.figure(figsize=(10, 6))
sns.barplot(x=fuente_count.index, y=fuente_count.values)
plt.title('Distribución de las Principales Fuentes de Noticias')
plt.xlabel('Fuente de Noticias')
plt.ylabel('Número de Noticias')
plt.xticks(rotation=90)  # Rotar las etiquetas para mayor claridad
plt.show()

# %%
# Calcular la longitud del texto
df_combined['Text_Length'] = df_combined['Text'].apply(len)

# Histograma de la longitud del texto
plt.figure(figsize=(10, 6))
sns.histplot(data=df_combined, x='Text_Length', hue='Category', bins=30, kde=True)
plt.title('Distribución de la Longitud del Texto (Fake vs Real)')
plt.xlabel('Número de Caracteres en el Texto')
plt.ylabel('Frecuencia')
plt.show()

# %%
from wordcloud import WordCloud

# Filtrar las noticias falsas y reales
fake_news = ' '.join(df_combined[df_combined['Category'] == 0]['Text'])
real_news = ' '.join(df_combined[df_combined['Category'] == 1]['Text'])

# Generar el wordcloud para fake news
plt.figure(figsize=(10, 6))
wordcloud_fake = WordCloud(width=800, height=400, background_color='black').generate(fake_news)
plt.imshow(wordcloud_fake, interpolation='bilinear')
plt.title('Nube de Palabras - Fake News')
plt.axis('off')
plt.show()

# Generar el wordcloud para real news
plt.figure(figsize=(10, 6))
wordcloud_real = WordCloud(width=800, height=400, background_color='black').generate(real_news)
plt.imshow(wordcloud_real, interpolation='bilinear')
plt.title('Nube de Palabras - Real News')
plt.axis('off')
plt.show()
