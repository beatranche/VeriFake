# %%
import pandas as pd
import numpy as np
import torch
import spacy
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import re 
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, TrainingArguments, Trainer
from datasets import Dataset
from torch.utils.data import DataLoader
from transformers import DataCollatorWithPadding
from sklearn.linear_model import SGDClassifier, ElasticNetCV
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC

# %%
import warnings
warnings.filterwarnings("ignore")

# Descargar stopwords
nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('spanish'))

# Cargar modelo de spacy
nlp = spacy.load('es_core_news_sm')

# Función de preprocesamiento
def preprocess_text(text):
    text = re.sub(r'[^a-zA-ZáéíóúñÁÉÍÓÚÑ\s]', '', text)  # Eliminar caracteres no alfabéticos
    text = text.lower()  # Convertir a minúsculas
    doc = nlp(text)
    return ' '.join([token.lemma_ for token in doc if token.text not in stop_words and not token.is_punct])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eslab\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Cargar y preprocesar datos
df1 = pd.read_csv("hf://datasets/mariagrandury/fake_news_corpus_spanish/test.csv")
df2 = pd.read_csv("https://huggingface.co/datasets/sayalaruano/FakeNewsCorpusSpanish/raw/main/train.csv")
df3 = pd.read_csv('https://drive.google.com/uc?export=download&id=16925KI3IS1_IajpDS65VR8gInzWsQ1ZR')

# %%
# Renombrar columnas y procesar texto
for df in [df1, df2, df3]:
    df.rename(columns={"ID": "Id", "CATEGORY": "Category", "TOPICS": "Topic", "SOURCE": "Source", "HEADLINE": "Headline", "TEXT": "Text", "LINK": "Link"}, inplace=True)
    df['Category'].replace({'Fake': False, 'True': True, 'False': False}, inplace=True)
    df['Category'] = df['Category'].map({True: 1, False: 0})
    df['Text'] = df['Text'].apply(preprocess_text)

# %%
# Combinar los dataframes
df_combined = pd.concat([df1, df2, df3])

# Limpiar datos faltantes
df_combined['Headline'].fillna(df_combined['Text'].apply(lambda x: ' '.join(x.split()[:10])), inplace=True)
df_combined.dropna(subset=['Source'], inplace=True)
df_combined['Link'].fillna('Unknown', inplace=True)

# %%
df_combined.head(3)
# Out:
#    Id  Category     Topic         Source  \
# 0   1         1  Covid-19  El Economista
# 1   2         0  Política     El matinal
# 2   3         1  Política        El País
#
#                                             Headline  \
# 0                       Covid-19: mentiras que matan
# 1  El Gobierno podrá acceder a las IPs de los móv...
# 2  La comunidad musulmana catalana denuncia a Vox...
#
#                                                 Text  \
# 0  control covid sólo tema médico resto personal ...
# 1  gobierno pedro sánchez pablo iglesia encontrar...
# 2  tres federación agrupar   mezquita llevar fisc...
#
#                                                 Link
# 0  https://www.eleconomista.com.mx/opinion/Covid-...
# 1  https://www.elmatinal.com/espana-ultima-hora/e...
# 2  https://elpais.com/espana/elecciones-catalanas...

# %%
df_google_news = pd.read_csv('data/real_news.csv')
df_concat = pd.read_csv('data/google_scrap.csv')
df_more = pd.read_csv('data/more.csv')
df_news = pd.read_csv('data/news.csv')
df_real_news_google = pd.read_csv('data/real_news_google.csv')
df_real_news = pd.read_csv('data/real_news.csv')

# %%
df_concat = pd.concat([df_google_news, df_concat, df_more, df_news, df_real_news_google, df_real_news])

# %%
df_concat.value_counts()
# Out:
# query             position  title                                                                                                              body                                                                                                                                              posted           source                    link
# Últimas noticias  30        Guerra Israel-Palestina y Rusia-Ucrania: últimas noticias del 15 de octubre                                        Sigue en vivo y en directo la última hora del conflicto que libra Israel en \nGaza y Líbano, la guerra entre Rusia y Ucrania y la última hora...  Hace 5 días      Diario AS                 https://as.com/actualidad/politica/guerra-israel-palestina-y-rusia-ucrania-en-directo-netanyahu-detalla-a-eeuu-como-sera-su-posible-ataque-a-iran-n/              1
# Name: count, Length: 831, dtype: int64

# %%
df_concat.isnull().sum()
# Out:
# query        0
# position     0
# title        3
# body        79
# posted      79
# source       3
# link         0
# dtype: int64

# %%
df_concat.duplicated().sum()
# Out:
# 308

# %%
df_concat = df_concat.drop_duplicates()

# %%
df_concat.isnull().sum()
# Out:
# query        0
# position     0
# title        3
# body        71
# posted      71
# source       3
# link         0
# dtype: int64

# %%
# Eliminar null values
df_concat.dropna(inplace=True)

# %%
df_concat.shape
# Out:
# (831, 7)

# %%
# Renombrar columnas
df_concat = df_concat.rename(columns={'title': 'Headline', 'body': 'Text', 'link': 'Link'})

# Añadir columna 'Category' con valor 1 en todas las filas
df_concat['Category'] = 1

# Verificar los cambios
df_concat.head()
# Out:
#   query  position                                           Headline  \
# 0  para         1  Muriqi, un regreso perfecto para un Mallorca q...
# 1  para         2  Intervienen en Chiclana una red de grandes dim...
# 2  para         3  Jota Jordi suelta esta bomba en directo para h...
# 7  para         8  El referéndum en Moldavia para blindar la vía ...
# 8  para         9  Adiós al transporte público gratuito para todo...
#
#                                                 Text           posted  \
# 0  El 'pirata' volvió al equipo tras un mes de le...  hace 20 minutos
# 1  La Policía autonómica ha rescatado a una docen...  hace 30 minutos
# 2  El tertuliano del Chiringuito está tan seguro ...     hace 3 horas
# 7  Moldavia denuncia un ataque “sin precedentes” ...    hace 14 horas
# 8  El descuento en el transporte público finaliza...     hace 5 horas
#
#             source                                               Link  \
# 0        Marca.com  https://www.marca.com/futbol/mallorca/2024/10/...
# 1  Diario de Cádiz  https://www.diariodecadiz.es/chiclana/intervie...
# 2        Diario AS  https://as.com/futbol/videos/jota-jordi-suelta...
# 7          EL PAÍS  https://elpais.com/internacional/2024-10-20/el...
# 8        20Minutos  https://www.20minutos.es/lainformacion/economi...
#
#    Category
# 0         1
# 1         1
# 2         1
# 7         1
# 8         1

# %%
df_concat.shape
# Out:
# (831, 8)

# %%
# Asegúrate de que ambas columnas de los datasets tengan los mismos nombres
df_concat = df_concat[['Headline', 'Text', 'Link', 'Category']]  # Seleccionar las columnas que coinciden
df_combined = df_combined[['Id', 'Category', 'Topic', 'Source', 'Headline', 'Text', 'Link']]  # Ya está organizado

# Añadir columnas vacías a df_google_scrap para alinearlo con el segundo dataset
df_concat['Id'] = range(1, len(df_concat) + 1)  # Asignar un Id único a cada fila
df_concat['Topic'] = 'Unknown'  # Añadir columna Topic con un valor predeterminado
df_concat['Source'] = 'Unknown'  # Añadir columna Source con un valor predeterminado

# Ordenar las columnas para que coincidan con el segundo dataset
df_concat = df_concat[['Id', 'Category', 'Topic', 'Source', 'Headline', 'Text', 'Link']]

# Combinar ambos datasets
df_combined = pd.concat([df_combined, df_concat], ignore_index=True)

# Verificar el dataset combinado
df_combined.head()
# Out:
#    Id  Category     Topic         Source  \
# 0   1         1  Covid-19  El Economista
# 1   2         0  Política     El matinal
# 2   3         1  Política        El País
# 3   4         0  Política     AFPFactual
# 4   5         1  Sociedad   La Republica
#
#                                             Headline  \
# 0                       Covid-19: mentiras que matan
# 1  El Gobierno podrá acceder a las IPs de los móv...
# 2  La comunidad musulmana catalana denuncia a Vox...
# 3  dar conocer dato electoral preliminar persona ...
# 4  El censo poblacional 2018 tendrá un costo de $...
#
#                                                 Text  \
# 0  control covid sólo tema médico resto personal ...
# 1  gobierno pedro sánchez pablo iglesia encontrar...
# 2  tres federación agrupar   mezquita llevar fisc...
# 3  dar conocer dato electoral preliminar persona ...
# 4  primero fase censo virtual solo abril próximo ...
#
#                                                 Link
# 0  https://www.eleconomista.com.mx/opinion/Covid-...
# 1  https://www.elmatinal.com/espana-ultima-hora/e...
# 2  https://elpais.com/espana/elecciones-catalanas...
# 3                         https://perma.cc/GYE6-SPMB
# 4  https://www.larepublica.co/economia/el-censo-p...

# %%
df_combined.shape
# Out:
# (2367, 7)

# %%
df_combined.isnull().sum()
# Out:
# Id          0
# Category    0
# Topic       0
# Source      0
# Headline    0
# Text        0
# Link        0
# dtype: int64

# %%
df_combined.duplicated().sum()
# Out:
# 0

# %%
df_fake_news = pd.read_csv('data/headline_links_combined.csv')

# %%
df_fake_news.head()
# Out:
#    Index                                           Headline  \
# 0      0  “En el AIFA hay más ratas que vuelos”, afirmau...
# 1      0  Afirmaciones similares circulan en Twitter (1,...
# 2      0  El Aeropuerto Internacional Felipe Ángeles (AI...
# 3      0  Sin embargo, el Felipe Ángeles ha tardado en a...
# 4      0  “La gente sigue sin darse cuenta pero esto es ...
#
#                                                 Link
# 0                                 https://aifa.aero/
# 1  https://www.nytimes.com/es/2022/03/25/espanol/...
# 2                           https://www.aicm.com.mx/
# 3  https://www.aicm.com.mx/acercadelaicm/archivos...
# 4  https://www.latribune.fr/entreprises-finance/b...

# %%
df_fake_news.shape
# Out:
# (12514, 3)

# %%
df_fake_news.isnull().sum()
# Out:
# Index       0
# Headline    0
# Link        0
# dtype: int64

# %%
df_fnews = df_fake_news.head(1000)

# %%
df_fnews = df_fnews.rename(columns={'Headline': 'Text'})
df_fnews['Category'] = 0

# %%
df_fnews.head()
# Out:
#    Index                                               Text  \
# 0      0  “En el AIFA hay más ratas que vuelos”, afirmau...
# 1      0  Afirmaciones similares circulan en Twitter (1,...
# 2      0  El Aeropuerto Internacional Felipe Ángeles (AI...
# 3      0  Sin embargo, el Felipe Ángeles ha tardado en a...
# 4      0  “La gente sigue sin darse cuenta pero esto es ...
#
#                                                 Link  Category
# 0                                 https://aifa.aero/         0
# 1  https://www.nytimes.com/es/2022/03/25/espanol/...         0
# 2                           https://www.aicm.com.mx/         0
# 3  https://www.aicm.com.mx/acercadelaicm/archivos...         0
# 4  https://www.latribune.fr/entreprises-finance/b...         0

# %%
# Obtener las columnas comunes
common_columns = df_combined.columns.intersection(df_fnews.columns)

# %%
common_columns
# Out:
# Index(['Category', 'Text', 'Link'], dtype='object')

# %%
df_combined_filtered = df_combined[common_columns]

# %%
# Concatenar ambos DataFrames usando las columnas comunes
df_combined = pd.concat([df_combined, df_fnews], ignore_index=True)

# Ver las primeras filas del nuevo DataFrame unido
df_combined.head()
# Out:
#     Id  Category     Topic         Source  \
# 0  1.0         1  Covid-19  El Economista
# 1  2.0         0  Política     El matinal
# 2  3.0         1  Política        El País
# 3  4.0         0  Política     AFPFactual
# 4  5.0         1  Sociedad   La Republica
#
#                                             Headline  \
# 0                       Covid-19: mentiras que matan
# 1  El Gobierno podrá acceder a las IPs de los móv...
# 2  La comunidad musulmana catalana denuncia a Vox...
# 3  dar conocer dato electoral preliminar persona ...
# 4  El censo poblacional 2018 tendrá un costo de $...
#
#                                                 Text  \
# 0  control covid sólo tema médico resto personal ...
# 1  gobierno pedro sánchez pablo iglesia encontrar...
# 2  tres federación agrupar   mezquita llevar fisc...
# 3  dar conocer dato electoral preliminar persona ...
# 4  primero fase censo virtual solo abril próximo ...
#
#                                                 Link  Index
# 0  https://www.eleconomista.com.mx/opinion/Covid-...    NaN
# 1  https://www.elmatinal.com/espana-ultima-hora/e...    NaN
# 2  https://elpais.com/espana/elecciones-catalanas...    NaN
# 3                         https://perma.cc/GYE6-SPMB    NaN
# 4  https://www.larepublica.co/economia/el-censo-p...    NaN

# %%
df_combined.shape
# Out:
# (3367, 8)

# %%
df_combined.isnull().sum()
# Out:
# Id          1000
# Category       0
# Topic       1000
# Source      1000
# Headline    1000
# Text           0
# Link           0
# Index       2367
# dtype: int64

# %%
columns_to_drop = ['Topic', 'Source', 'Headline','Index', 'Id']  # Cambia los nombres de las columnas según sea necesario

# Eliminar las columnas específicas
df_combined = df_combined.drop(columns=columns_to_drop)

# %%
# Extraer el nombre del dominio
df_combined['Source'] = df_combined['Link'].str.extract(r'https?://(?:www\.)?([^/]+)')

# %%
df_combined['Source'] = df_combined['Source'].str.split('.').str[0]

# %%
# Mostrar el DataFrame limpio
display(df_combined)
# Out:
#       Category                                               Text  \
# 0            1  control covid sólo tema médico resto personal ...
# 1            0  gobierno pedro sánchez pablo iglesia encontrar...
# 2            1  tres federación agrupar   mezquita llevar fisc...
# 3            0  dar conocer dato electoral preliminar persona ...
# 4            1  primero fase censo virtual solo abril próximo ...
# ...        ...                                                ...
# 3362         0  Nos habéis preguntado por WhatsApp, Twitter e ...
# 3363         0  En la parte superior del falso artículo se pue...
# 3364         0  Si se pega ese enlace en el navegador,sale un ...
# 3365         0  En ningún lugar de ese artículo se habla de Sa...
# 3366         0  Nos habéis preguntado mucho por nuestro servic...
#
#                                                    Link        Source
# 0     https://www.eleconomista.com.mx/opinion/Covid-...  eleconomista
# 1     https://www.elmatinal.com/espana-ultima-hora/e...     elmatinal
# 2     https://elpais.com/espana/elecciones-catalanas...        elpais
# 3                            https://perma.cc/GYE6-SPMB         perma
# 4     https://www.larepublica.co/economia/el-censo-p...   larepublica
# ...                                                 ...           ...
# 3362  https://www.osi.es/es/actualidad/avisos/2020/0...           osi
# 3363  https://maldita.es/malditobulo/2020/05/12/sms-...       maldita
# 3364                          https://www.mercadona.es/     mercadona
# 3365  https://maldita.es/malditobulo/2020/04/06/merc...       maldita
# 3366  https://maldita.es/malditobulo/2020/04/01/tarj...       maldita
#
# [3367 rows x 4 columns]

# %%
df_combined.head(5)
# Out:
#    Category                                               Text  \
# 0         1  control covid sólo tema médico resto personal ...
# 1         0  gobierno pedro sánchez pablo iglesia encontrar...
# 2         1  tres federación agrupar   mezquita llevar fisc...
# 3         0  dar conocer dato electoral preliminar persona ...
# 4         1  primero fase censo virtual solo abril próximo ...
#
#                                                 Link        Source
# 0  https://www.eleconomista.com.mx/opinion/Covid-...  eleconomista
# 1  https://www.elmatinal.com/espana-ultima-hora/e...     elmatinal
# 2  https://elpais.com/espana/elecciones-catalanas...        elpais
# 3                         https://perma.cc/GYE6-SPMB         perma
# 4  https://www.larepublica.co/economia/el-censo-p...   larepublica

# %%
min_samples_threshold = 5
source_counts = df_combined['Source'].value_counts()
sources_to_keep = source_counts[source_counts >= min_samples_threshold].index

# Agrupar fuentes raras en "Otros"
df_combined['Source'] = df_combined['Source'].apply(lambda x: x if x in sources_to_keep else "Otros")

# %%
df_combined['Source'].value_counts()
# Out:
# Source
# Otros                728
# maldita              335
# elpais               213
# eldizque             143
# osi                  123
#                     ...
# 20minutos              5
# telecinco              5
# laopiniondemalaga      5
# informacion            5
# farodevigo             5
# Name: count, Length: 96, dtype: int64

# %%
df_combined.shape
# Out:
# (3367, 4)

# %%
# División de datos de entrenamiento y prueba
X = df_combined['Text']
y = df_combined['Source']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
# Vectorización TF-IDF
# Aumentar el número de características en el vectorizador TF-IDF
# Convertir el conjunto de stopwords a una lista
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 3), stop_words=list(stop_words))

# Transformar los datos de entrenamiento y prueba
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# Filtrado de clases pequeñas
unique_classes, counts = np.unique(y_train, return_counts=True)
class_distribution = pd.DataFrame({'Class': unique_classes, 'Count': counts})
min_samples_threshold = 3
classes_to_keep = class_distribution[class_distribution['Count'] >= min_samples_threshold]['Class'].tolist()

y_train_filtered = y_train[y_train.isin(classes_to_keep)]
X_train_filtered = X_train_vec[y_train.isin(classes_to_keep)]

# %%
# Resampling con SMOTE
smote = SMOTE(random_state=42, k_neighbors=1)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_filtered, y_train_filtered)

# %%
# Ajuste de hiperparámetros con GridSearchCV para RandomForest
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
}
rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5)
grid_search.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]})

# %%
grid_search.best_params_
# Out:
# {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200}

# %%
# Clasificadores: Logistic Regression, Ridge, Random Forest, SVM
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Ridge Classifier": RidgeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC()
}

# %%
classifiers = {


    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "SGD Classifier": SGDClassifier(),
    "ElasticNet": ElasticNetCV(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": MultinomialNB(),
    "MLP Classifier": MLPClassifier(max_iter=500),
    "Linear SVC": LinearSVC(),
    "Gaussian Naive Bayes": GaussianNB(),
}

# %%
# Entrenar los modelos y generar predicciones
predictions = {}
for name, clf in classifiers.items():
    clf.fit(X_train_resampled, y_train_resampled)
    predictions[name] = clf.predict(X_test_vec)

# %%
# Reportes de clasificación para cada modelo
for name, preds in predictions.items():
    print(f"\n{name} Report:")
    print(classification_report(y_test, preds))
# Out:
# Logistic Regression Report:
#                      precision    recall  f1-score   support
#
#           20minutos       0.00      0.00      0.00         0
#               Otros       0.47      0.50      0.48       107
#                 abc       0.36      0.44      0.40         9
#       alertadigital       0.00      0.00      0.00         3
#                 api       0.00      0.00      0.00         2
#               apisa       0.00      0.00      0.00         2
#   argumentopolitico       0.00      0.00      0.00         2
#   aristeguinoticias       0.00      0.00      0.00         2
#                  as       1.00      0.50      0.67         2
#         atresplayer       0.00      0.00      0.00         4
#                 bbc       0.22      0.44      0.30         9
#           cadenaser       0.00      0.00      0.00         3
#             caritas       0.00      0.00      0.00         3
#            censura0       0.30      0.50      0.38         6
#           cincodias       0.00      0.00      0.00         2
#              clarin       0.00      0.00      0.00         1
#          cnnespanol       0.50      0.14      0.22         7
#        diariodeleon       0.00      0.00      0.00         2
#         diariovasco       0.00      0.00      0.00         1
#          doesfollow       0.00      0.00      0.00         1
#          elcomercio       0.50      0.50      0.50         2
#      elconfidencial       0.00      0.00      0.00         4
#            eldiario       0.00      0.00      0.00         2
#            eldizque       0.60      0.65      0.62        23
#        eleconomista       0.50      0.20      0.29         5
#        elfinanciero       0.17      0.10      0.12        10
#             elmundo       1.00      0.33      0.50         3
#        elmundotoday       0.00      0.00      0.00         0
#              elpais       0.40      0.53      0.45        32
#         elperiodico       0.00      0.00      0.00         2
#       elruinaversal       0.76      1.00      0.87        13
#            eltiempo       0.00      0.00      0.00         2
#         eluniversal       0.20      0.20      0.20        15
#                  es       0.00      0.00      0.00         2
#                espn       0.00      0.00      0.00         0
#         europapress       0.00      0.00      0.00         2
#           excelsior       0.00      0.00      0.00         5
#           expansion       1.00      0.40      0.57         5
#            facebook       0.00      0.00      0.00         6
#             fanpage       0.00      0.00      0.00         1
#                 faq       0.00      0.00      0.00         0
#          farodevigo       0.00      0.00      0.00         1
#              forbes       0.13      0.40      0.20         5
#            france24       0.33      1.00      0.50         1
#                 gob       0.00      0.00      0.00         2
#          haynoticia       0.00      0.00      0.00         4
#      huffingtonpost       0.00      0.00      0.00         5
#        ilmessaggero       0.00      0.00      0.00         1
#              incibe       0.00      0.00      0.00         3
#         informacion       1.00      1.00      1.00         1
#           instagram       0.00      0.00      0.00         2
#            interior       0.00      0.00      0.00         1
#             jornada       0.00      0.00      0.00         3
#            lanacion       0.00      0.00      0.00         2
#   laopiniondemalaga       0.00      0.00      0.00         1
#             larazon       1.00      0.50      0.67         2
#         larepublica       0.00      0.00      0.00         1
#        lavanguardia       0.00      0.00      0.00         8
#        lavozpopular       0.00      0.00      0.00         2
#         leon24horas       1.00      1.00      1.00         1
#         leonoticias       1.00      1.00      1.00         1
#           lmneuquen       0.00      0.00      0.00         1
#             maldita       0.38      0.38      0.38        47
#                 mam       0.00      0.00      0.00         1
#               marca       0.00      0.00      0.00         2
# mediterraneodigital       0.00      0.00      0.00         3
#        eleconomista       1.00      0.20      0.33         5
#        elfinanciero       0.00      0.00      0.00        10
#             elmundo       1.00      0.33      0.50         3
#              elpais       0.59      0.41      0.48        32
#         elperiodico       0.00      0.00      0.00         2
#       elruinaversal       0.79      0.85      0.81        13
#            eltiempo       0.00      0.00      0.00         2
#         eluniversal       0.00      0.00      0.00        15
#                  es       0.00      0.00      0.00         2
#         europapress       0.00      0.00      0.00         2
#           excelsior       0.00      0.00      0.00         5
#           expansion       1.00      0.40      0.57         5
#            facebook       0.00      0.00      0.00         6
#             fanpage       0.00      0.00      0.00         1
#                 faq       0.00      0.00      0.00         0
#          farodevigo       0.00      0.00      0.00         1
#              forbes       0.00      0.00      0.00         5
#            france24       0.00      0.00      0.00         1
#                 gob       0.00      0.00      0.00         2
#          haynoticia       0.00      0.00      0.00         4
#      huffingtonpost       0.00      0.00      0.00         5
#        ilmessaggero       0.00      0.00      0.00         1
#              incibe       0.00      0.00      0.00         3
#         informacion       1.00      1.00      1.00         1
#           instagram       0.00      0.00      0.00         2
#            interior       0.00      0.00      0.00         1
#             jornada       0.00      0.00      0.00         3
#            lanacion       0.00      0.00      0.00         2
#   laopiniondemalaga       0.00      0.00      0.00         1
#             larazon       1.00      0.50      0.67         2
#         larepublica       0.00      0.00      0.00         1
#        lavanguardia       1.00      0.12      0.22         8
#        lavozpopular       0.00      0.00      0.00         2
#         leon24horas       1.00      1.00      1.00         1
#         leonoticias       1.00      1.00      1.00         1
#           lmneuquen       0.00      0.00      0.00         1
#             maldita       0.32      0.83      0.46        47
#                 mam       0.00      0.00      0.00         1
#               marca       0.00      0.00      0.00         2
# mediterraneodigital       0.00      0.00      0.00         3
#           mercadona       0.00      0.00      0.00         3
#             milenio       0.00      0.00      0.00        18
#         modonoticia       0.67      0.40      0.50         5
#              mossos       0.00      0.00      0.00         2
#         mvsnoticias       0.00      0.00      0.00         2
#             nytimes       0.00      0.00      0.00         2
#            ondacero       1.00      0.25      0.40         4
#                 osi       0.27      0.16      0.20        19
#            pagina12       0.00      0.00      0.00         0
#               perma       0.00      0.00      0.00         6
#             poynter       0.00      0.00      0.00         2
#             proceso       0.00      0.00      0.00         3
#     redaccionmedica       0.00      0.00      0.00         2
#           retroceso       0.33      0.25      0.29         4
#                rtve       0.33      0.25      0.29         4
#        saludneuquen       0.00      0.00      0.00         3
#             twitter       0.14      0.10      0.12        10
#                 ucm       0.00      0.00      0.00         0
#                 web       0.50      0.14      0.22         7
#              xataka       1.00      0.14      0.25         7
#
#            accuracy                           0.37       506
#           macro avg       0.22      0.14      0.15       506
#        weighted avg       0.32      0.37      0.29       506
#
#
# SVM Report:
#                      precision    recall  f1-score   support
#
#               Otros       0.28      0.99      0.43       107
#                 abc       1.00      0.44      0.62         9
#       alertadigital       0.00      0.00      0.00         3
#                 api       0.00      0.00      0.00         2
#               apisa       0.00      0.00      0.00         2
#   argumentopolitico       0.00      0.00      0.00         2
#   aristeguinoticias       0.00      0.00      0.00         2
#                  as       0.00      0.00      0.00         2
#         atresplayer       0.00      0.00      0.00         4
#                 bbc       1.00      0.11      0.20         9
